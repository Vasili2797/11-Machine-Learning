# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
# !pip install delayed
# Out:
# Collecting delayed
#   Downloading delayed-0.11.0b1-py2.py3-none-any.whl (19 kB)
# Collecting hiredis
#   Downloading hiredis-1.1.0-cp37-cp37m-win_amd64.whl (15 kB)
# Collecting redis
#   Downloading redis-3.5.3-py2.py3-none-any.whl (72 kB)
# Installing collected packages: redis, hiredis, delayed
# Successfully installed delayed-0.11.0b1 hiredis-1.1.0 redis-3.5.3

# %%
from sklearn.utils.fixes import delayed

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Create our features
 # YOUR CODE HERE
X = df.drop(columns="loan_status")
# Create our target
 # YOUR CODE HERE
y=df["loan_status"].tolist()

# %%
X = pd.get_dummies(df.drop('loan_status', axis=1))
y = df[['loan_status']]

# %%
#X.describe()
X.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    10500.0    0.1719       375.35     66000.0  27.24          0.0
# 1    25000.0    0.2000       929.09    105000.0  20.23          0.0
# 2    20000.0    0.2000       529.88     56000.0  24.26          0.0
# 3    10000.0    0.1640       353.55     92000.0  31.44          0.0
# 4    22000.0    0.1474       520.39     52000.0  18.76          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  issue_d_Mar-2019  \
# 0             0.0       8.0      0.0     1609.0  ...                 1
# 1             0.0      17.0      1.0    18368.0  ...                 1
# 2             0.0       8.0      0.0    13247.0  ...                 1
# 3             1.0      10.0      1.0    17996.0  ...                 1
# 4             1.0      14.0      0.0     9091.0  ...                 1
#
#    pymnt_plan_n  initial_list_status_f  initial_list_status_w  \
# 0             1                      0                      1
# 1             1                      0                      1
# 2             1                      0                      1
# 3             1                      0                      1
# 4             1                      0                      1
#
#    next_pymnt_d_Apr-2019  next_pymnt_d_May-2019  application_type_Individual  \
# 0                      0                      1                            1
# 1                      0                      1                            1
# 2                      0                      1                            1
# 3                      0                      1                            1
# 4                      0                      1                            1
#
#    application_type_Joint App  hardship_flag_N  debt_settlement_flag_N
# 0                           0                1                       1
# 1                           0                1                       1
# 2                           0                1                       1
# 3                           0                1                       1
# 4                           0                1                       1
#
# [5 rows x 95 columns]

# %%
# Fitting and encoding the columns with the LabelEncoder
#le = LabelEncoder()

# Encoding homeowner column
#le.fit(X["home_ownership"])
#X["home_ownership"] = le.transform(X["home_ownership"])

# Encoding verification status column
#le.fit(X["verification_status"])
#X["verification_status"] = le.transform(X["verification_status"])

#X

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  issue_d_Mar-2019  pymnt_plan_n  \
# count   68817.000000  ...      68817.000000       68817.0
# mean    17604.142828  ...          0.177238           1.0
# std     21835.880400  ...          0.381873           0.0
# min         0.000000  ...          0.000000           1.0
# 25%      6293.000000  ...          0.000000           1.0
# 50%     12068.000000  ...          0.000000           1.0
# 75%     21735.000000  ...          0.000000           1.0
# max    587191.000000  ...          1.000000           1.0
#
#        initial_list_status_f  initial_list_status_w  next_pymnt_d_Apr-2019  \
# count           68817.000000           68817.000000           68817.000000
# mean                0.123879               0.876121               0.383161
# std                 0.329446               0.329446               0.486161
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               1.000000               0.000000
# 50%                 0.000000               1.000000               0.000000
# 75%                 0.000000               1.000000               1.000000
# max                 1.000000               1.000000               1.000000
#
#        next_pymnt_d_May-2019  application_type_Individual  \
# count           68817.000000                 68817.000000
# mean                0.616839                     0.860340
# std                 0.486161                     0.346637
# min                 0.000000                     0.000000
# 25%                 0.000000                     1.000000
# 50%                 1.000000                     1.000000
# 75%                 1.000000                     1.000000
# max                 1.000000                     1.000000
#
#        application_type_Joint App  hardship_flag_N  debt_settlement_flag_N
# count                68817.000000          68817.0                 68817.0
# mean                     0.139660              1.0                     1.0
# std                      0.346637              0.0                     0.0
# min                      0.000000              1.0                     1.0
# 25%                      0.000000              1.0                     1.0
# 50%                      0.000000              1.0                     1.0
# 75%                      0.000000              1.0                     1.0
# max                      1.000000              1.0                     1.0
#
# [8 rows x 95 columns]

# %%
# Check the balance of our target values
# YOUR CODE HERE
df['loan_status'].value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
# Split the X and y into X_train, X_test, y_train, y_test
# YOUR CODE HERE
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X, y, random_state=1, stratify=y)

# %%
X_train.shape
# Out:
# (51612, 95)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
# YOUR CODE HERE autocomplete or shift-tab
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
# YOUR CODE HERE
X_scaler = scaler.fit(X)

X_train_scaled = X_scaler.transform(X)
#X_test_scaled = X_scaler.transform(X_test)

# %%
# Scale the training and testing data
# YOUR CODE HERE

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
# YOUR CODE HERE
from imblearn.ensemble import BalancedRandomForestClassifier

model=BalancedRandomForestClassifier(random_state=1,class_weight='balanced',sampling_strategy='not minority')
model.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(class_weight='balanced', random_state=1,
#                                sampling_strategy='not minority')

# %%
# Calculated the balanced accuracy score
# YOUR CODE HERE
from sklearn.metrics import balanced_accuracy_score

predictions = model.predict(X_test)
balanced_accuracy_score(y_test, predictions)
# Out:
# 0.7322973196191949

# %%
# Display the confusion matrix
# YOUR CODE HERE
from sklearn.metrics import confusion_matrix

predictions = rf.predict(X_test)
results = pd.DataFrame({"Prediction": predictions,
                        "Actual": y_test}).reset_index(drop=True)
results.head()

confusion_matrix(y_test, predictions)
# Out:
# array([[   50,    37],
#        [ 1885, 15233]], dtype=int64)

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
y_pred_model = model.predict(X_test)
print(classification_report_imbalanced(y_test, y_pred_model))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.03      0.57      0.89      0.05      0.72      0.50        87
#    low_risk       1.00      0.89      0.57      0.94      0.72      0.53     17118
#
# avg / total       0.99      0.89      0.58      0.94      0.72      0.53     17205

# %%
# List the features sorted in descending order by feature importance
# YOUR CODE HERE
import pandas as pd
feature_importances = pd.DataFrame(model.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
print(feature_importances)
# Out:
#                                      importance
# issue_d_Mar-2019                       0.047049
# total_rec_int                          0.033974
# mths_since_recent_bc                   0.033044
# last_pymnt_amnt                        0.032271
# total_bc_limit                         0.026141
# mo_sin_old_il_acct                     0.023513
# max_bal_bc                             0.023495
# total_pymnt_inv                        0.023281
# bc_open_to_buy                         0.022609
# avg_cur_bal                            0.021671
# il_util                                0.021376
# total_il_high_credit_limit             0.020940
# mths_since_rcnt_il                     0.020797
# mo_sin_old_rev_tl_op                   0.020710
# int_rate                               0.020615
# mo_sin_rcnt_rev_tl_op                  0.020305
# revol_bal                              0.018455
# installment                            0.018429
# total_rev_hi_lim                       0.018188
# total_pymnt                            0.018157
# all_util                               0.018053
# mths_since_recent_inq                  0.017644
# num_rev_accts                          0.016857
# total_bal_il                           0.016408
# mo_sin_rcnt_tl                         0.016060
# dti                                    0.016009
# out_prncp                              0.015728
# num_il_tl                              0.015611
# tot_coll_amt                           0.015469
# total_rec_prncp                        0.015394
# ...                                         ...
# num_tl_90g_dpd_24m                     0.003066
# pub_rec                                0.002629
# next_pymnt_d_Apr-2019                  0.002447
# pub_rec_bankruptcies                   0.002389
# home_ownership_ANY                     0.001997
# initial_list_status_f                  0.001918
# collections_12_mths_ex_med             0.001859
# home_ownership_RENT                    0.001788
# inq_last_6mths                         0.001715
# verification_status_Verified           0.001657
# initial_list_status_w                  0.001360
# home_ownership_OWN                     0.000814
# application_type_Individual            0.000811
# verification_status_Not Verified       0.000779
# chargeoff_within_12_mths               0.000718
# application_type_Joint App             0.000581
# home_ownership_MORTGAGE                0.000546
# verification_status_Source Verified    0.000408
# total_rec_late_fee                     0.000080
# delinq_amnt                            0.000039
# recoveries                             0.000000
# pymnt_plan_n                           0.000000
# tax_liens                              0.000000
# collection_recovery_fee                0.000000
# num_tl_30dpd                           0.000000
# num_tl_120dpd_2m                       0.000000
# policy_code                            0.000000
# acc_now_delinq                         0.000000
# hardship_flag_N                        0.000000
# debt_settlement_flag_N                 0.000000
#
# [95 rows x 1 columns]

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
# YOUR CODE HERE
from sklearn.ensemble import AdaBoostClassifier
from sklearn import datasets

adaboost = AdaBoostClassifier(n_estimators=1000,
                         learning_rate=1,random_state=1)

model = adaboost.fit(X_train, y_train)

y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-457d797386c8> in <module>
#       7                          learning_rate=1,random_state=1)
#       8
# ----> 9 model = adaboost.fit(X_train, y_train)
#      10
#      11 y_pred = model.predict(X_test)
#
# ~\anaconda3\envs\viz-env\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     441
#     442         # Fit
# --> 443         return super().fit(X, y, sample_weight)
#     444
#     445     def _validate_estimator(self):
#
# ~\anaconda3\envs\viz-env\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     132                 X, y,
#     133                 sample_weight,
# --> 134                 random_state)
#     135
#     136             # Early termination
#
# ~\anaconda3\envs\viz-env\lib\site-packages\sklearn\ensemble\_weight_boosting.py in _boost(self, iboost, X, y, sample_weight, random_state)
#     501         """
#     502         if self.algorithm == 'SAMME.R':
# --> 503             return self._boost_real(iboost, X, y, sample_weight, random_state)
#     504
#     505         else:  # elif self.algorithm == "SAMME":
#
# ~\anaconda3\envs\viz-env\lib\site-packages\sklearn\ensemble\_weight_boosting.py in _boost_real(self, iboost, X, y, sample_weight, random_state)
#     511         estimator = self._make_estimator(random_state=random_state)
#     512
# --> 513         estimator.fit(X, y, sample_weight=sample_weight)
#     514
#     515         y_predict_proba = estimator.predict_proba(X)
#
# ~\anaconda3\envs\viz-env\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     900             sample_weight=sample_weight,
#     901             check_input=check_input,
# --> 902             X_idx_sorted=X_idx_sorted)
#     903         return self
#     904
#
# ~\anaconda3\envs\viz-env\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     200             for k in range(self.n_outputs_):
#     201                 classes_k, y_encoded[:, k] = np.unique(y[:, k],
# --> 202                                                        return_inverse=True)
#     203                 self.classes_.append(classes_k)
#     204                 self.n_classes_.append(classes_k.shape[0])
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~\anaconda3\envs\viz-env\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     259     ar = np.asanyarray(ar)
#     260     if axis is None:
# --> 261         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     262         return _unpack_tuple(ret)
#     263
#
# ~\anaconda3\envs\viz-env\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     318     if optional_indices:
#     319         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
# --> 320         aux = ar[perm]
#     321     else:
#     322         ar.sort()
#
# KeyboardInterrupt:

# %%
from imblearn.ensemble import EasyEnsembleClassifier

model2= EasyEnsembleClassifier(n_estimators=100, random_state=1)
model2 = model2.fit(X_train_scaled, y_train)

# %%
# Calculated the balanced accuracy score
# YOUR CODE HERE
from sklearn.metrics import balanced_accuracy_score

y_pred = model2.predict(X_test_scaled)

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.925427358175101

# %%
# Display the confusion matrix
# YOUR CODE HERE
confusion_matrix(y_test, y_pred)
# Out:
# array([[   79,     8],
#        [  979, 16139]], dtype=int64)

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    high_risk       0.07      0.91      0.14        87
#     low_risk       1.00      0.94      0.97     17118
#
#     accuracy                           0.94     17205
#    macro avg       0.54      0.93      0.55     17205
# weighted avg       0.99      0.94      0.97     17205

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
#     YOUR ANSWER HERE.
#
# 2. Which model had the best recall score?
#
#     YOUR ANSWER HERE.
#
# 3. Which model had the best geometric mean score?
#
#     YOUR ANSWER HERE.
#
# 4. What are the top three features?
#
#     YOUR ANSWER HERE.
